# %% [markdown]
# ## do one exercise on applied machine learning
# - model selection
# - one using the polynomial linear regression
#     - use differents power of polynomial n : 1,2,3...
#     - then verify teh least error for the which model using the J for x_cv.
# - using the neural network using different layer architecture.
#     - find which is best and why : using the x_cv error choose the model which one give less J for the x_cv.
#
# ### - take help or use data which is in the c2w2_lab model evaluation and selection and compare your results.
